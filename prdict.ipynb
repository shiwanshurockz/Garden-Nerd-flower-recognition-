# %%
import os

# %%
os.chdir('my_data')

# %%
for i in range(0, 103):
    os.mkdir('class_' + str(i))

# %%
import pandas as pd
import numpy as np
import shutil
import cv2

# %%
os.chdir('D:\\WORK\\hackerearth Challenge\\flower\\final segmented_image')
df = pd.read_csv('train.csv')

# %%
src = 'D:\\WORK\\hackerearth Challenge\\flower\\final segmented_image\\test\\'
dst = 'D:\\WORK\\hackerearth Challenge\\flower\\final segmented_image\\my_data\\test\\'

c = 0
for i, j in df.iterrows():
    c += 1
    temp = j
    os.chdir(src)
    img = cv2.imread(str(temp[0])+str('.jpg'))
    
    os.chdir(dst+'class_'+str(temp[1]))
    cv2.imwrite(str(temp[0])+'.jpg',img)
    if c % 500 == 0:
        print(c)

# %%
import pandas as pd
import os
import cv2, glob
import re
import random

os.chdir('D:\\WORK\\hackerearth Challenge\\flower\\final segmented_image\\my_data\\train\\')
dir_name = os.listdir()

for i in dir_name:
    
    os.chdir(i)
    list_jpg=os.listdir('D:\\WORK\\hackerearth Challenge\\flower\\final segmented_image\\my_data\\train\\'+str(i))
    random.seed(0)

    random.shuffle(list_jpg)

    split_1_m = int(0.9 * len(list_jpg))
    train_filenames = list_jpg[:split_1_m]
    valid_filenames = list_jpg[split_1_m:]

    print(str(len(train_filenames))+' '+str(len(valid_filenames))+' '+str(len(test_filenames)))    
    
    
    os.chdir('D:\\WORK\\hackerearth Challenge\\flower\\final segmented_image\\my_data\\train\\'+str(i))
    c= 0
    for file in train_filenames:
        c += 1
        os.chdir('D:\\WORK\\hackerearth Challenge\\flower\\final segmented_image\\my_data\\train\\'+str(i))
        img = cv2.imread(file, 1)
        print(file)
        os.chdir('D:\\WORK\\hackerearth Challenge\\flower\\final segmented_image\\my_data\\train1\\'+str(i))
        cv2.imwrite(file,img)

    os.chdir('D:\\WORK\\hackerearth Challenge\\flower\\final segmented_image\\my_data\\train\\'+str(i))
    for file in valid_filenames:
        os.chdir('D:\\WORK\\hackerearth Challenge\\flower\\final segmented_image\\my_data\\train\\'+str(i))
        img = cv2.imread(file, 1)
        os.chdir('D:\\WORK\\hackerearth Challenge\\flower\\final segmented_image\\my_data\\val\\'+str(i))
        cv2.imwrite(file, img)
        print('writing test')

    
    os.chdir('D:\\WORK\\hackerearth Challenge\\flower\\final segmented_image\\my_data\\train\\')

# %%
os.chdir('D:\\WORK\\hackerearth Challenge\\flower\\final segmented_image\\my_data\\train1\\')
# In[6]:

# %%
for i in range(1, 103):
    os.mkdir('class_'+str(i))

# %%
from keras.preprocessing.image import img_to_array
from keras.models import load_model
from keras.utils import get_file
import numpy as np
import argparse
import cv2
import os
import cvlib as cv
import keras
from skimage import io
from keras.models import load_model

os.chdir('D:\\WORK\\hackerearth Challenge\\flower\\final segmented_image')

model = keras.applications.inception_v3.InceptionV3(include_top = True, weights=None, input_tensor=None, input_shape=(256,256,3), pooling= 'max', classes=102)
model.load_weights('withoutclass4.h5')
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From C:\Users\shiwanshu\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
from keras.preprocessing.image import ImageDataGenerator

train_path = 'D:\\WORK\\hackerearth Challenge\\flower\\final segmented_image\\my_data\\train'
valid_path = 'D:\\WORK\\hackerearth Challenge\\flower\\final segmented_image\\my_data\\val'


train_batches = ImageDataGenerator(samplewise_center=True, rotation_range=30, shear_range=0.2, zoom_range=0.2, horizontal_flip=True, vertical_flip=True, rescale=1./255).flow_from_directory(
    train_path, target_size=(256, 256), batch_size=8,class_mode='categorical')
valid_batches = ImageDataGenerator(samplewise_center=True, rotation_range=30, shear_range=0.2, zoom_range=0.2, horizontal_flip=True, vertical_flip=True, rescale=1./255).flow_from_directory(
    valid_path, target_size=(256, 256), batch_size=4, class_mode='categorical')
# Out:
# Found 16638 images belonging to 102 classes.
# Found 1902 images belonging to 102 classes.

# %%
label_map = train_batches.class_indices

# %%
label_map = dict((v,k) for k,v in label_map.items())

# %%
label_map
# Out:
# {0: 'class_1',
#  1: 'class_10',
#  2: 'class_100',
#  3: 'class_101',
#  4: 'class_102',
#  5: 'class_11',
#  6: 'class_12',
#  7: 'class_13',
#  8: 'class_14',
#  9: 'class_15',
#  10: 'class_16',
#  11: 'class_17',
#  12: 'class_18',
#  13: 'class_19',
#  14: 'class_2',
#  15: 'class_20',
#  16: 'class_21',
#  17: 'class_22',
#  18: 'class_23',
#  19: 'class_24',
#  20: 'class_25',
#  21: 'class_26',
#  22: 'class_27',
#  23: 'class_28',
#  24: 'class_29',
#  25: 'class_3',
#  26: 'class_30',
#  27: 'class_31',
#  28: 'class_32',
#  29: 'class_33',
#  30: 'class_34',
#  31: 'class_35',
#  32: 'class_36',
#  33: 'class_37',
#  34: 'class_38',
#  35: 'class_39',
#  36: 'class_4',
#  37: 'class_40',
#  38: 'class_41',
#  39: 'class_42',
#  40: 'class_43',
#  41: 'class_44',
#  42: 'class_45',
#  43: 'class_46',
#  44: 'class_47',
#  45: 'class_48',
#  46: 'class_49',
#  47: 'class_5',
#  48: 'class_50',
#  49: 'class_51',
#  50: 'class_52',
#  51: 'class_53',
#  52: 'class_54',
# ...

# %%
test["category"] = [label_map[k] for k in predictions]

# %%
test_generator = ImageDataGenerator(samplewise_center=True, rotation_range=30, shear_range=0.2, zoom_range=0.2, horizontal_flip=True, vertical_flip=True, rescale=1./255).flow_from_directory(test_dir, 
target_size=(256, 256), 
batch_size=8,
class_mode='categorical')

# %%
import shutil
import os
import cv2
os.chdir('D:\\WORK\\hackerearth Challenge\\flower\\final segmented_image\\test')
filenames = os.listdir()
c = 0
res = []
for f in filenames:
    c += 1
    temp = []
    temp.append(str(f))

    face_crop = cv2.imread(f,1)
    face_crop = cv2.resize(face_crop, (256, 256))
    face_crop = face_crop.astype("float") / 255.0
    face_crop = img_to_array(face_crop)
    face_crop = np.expand_dims(face_crop, axis=0)

    # apply gender detection on face
    predict = model.predict(face_crop)[0]
    

    val = predict.argmax()
    temp.append(str(label_map[int(val)])[6 :])
    res.append(temp)
    
    if c % 100 == 0:
        print(c)
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000

# %%
res
# Out:
# [['18540.jpg', '30'],
#  ['18541.jpg', '31'],
#  ['18542.jpg', '29'],
#  ['18543.jpg', '72'],
#  ['18544.jpg', '68'],
#  ['18545.jpg', '29'],
#  ['18546.jpg', '88'],
#  ['18547.jpg', '9'],
#  ['18548.jpg', '43'],
#  ['18549.jpg', '28'],
#  ['18550.jpg', '87'],
#  ['18551.jpg', '19'],
#  ['18552.jpg', '20'],
#  ['18553.jpg', '87'],
#  ['18554.jpg', '88'],
#  ['18555.jpg', '23'],
#  ['18556.jpg', '23'],
#  ['18557.jpg', '23'],
#  ['18558.jpg', '88'],
#  ['18559.jpg', '19'],
#  ['18560.jpg', '36'],
#  ['18561.jpg', '80'],
#  ['18562.jpg', '3'],
#  ['18563.jpg', '93'],
#  ['18564.jpg', '76'],
#  ['18565.jpg', '29'],
#  ['18566.jpg', '19'],
#  ['18567.jpg', '43'],
#  ['18568.jpg', '30'],
#  ['18569.jpg', '57'],
#  ['18570.jpg', '88'],
#  ['18571.jpg', '87'],
#  ['18572.jpg', '37'],
#  ['18573.jpg', '37'],
#  ['18574.jpg', '43'],
#  ['18575.jpg', '25'],
#  ['18576.jpg', '25'],
#  ['18577.jpg', '28'],
#  ['18578.jpg', '88'],
#  ['18579.jpg', '29'],
#  ['18580.jpg', '86'],
# ...

# %%
f = '18585.jpg'

# %%
x.shape
# Out:
# (1, 256, 256, 3)

# %%
predict[0].max()
# Out:
# 1.0

# %%
res
# Out:
# [['18540', '1'],
#  ['18541', '1'],
#  ['18542', '1'],
#  ['18543', '1'],
#  ['18544', '1'],
#  ['18545', '1'],
#  ['18546', '1'],
#  ['18547', '1'],
#  ['18548', '1'],
#  ['18549', '1'],
#  ['18550', '1'],
#  ['18551', '1'],
#  ['18552', '1'],
#  ['18553', '1'],
#  ['18554', '1'],
#  ['18555', '1'],
#  ['18556', '1'],
#  ['18557', '1'],
#  ['18558', '1'],
#  ['18559', '1'],
#  ['18560', '1'],
#  ['18561', '1'],
#  ['18562', '1'],
#  ['18563', '1'],
#  ['18564', '1'],
#  ['18565', '1'],
#  ['18566', '1'],
#  ['18567', '1'],
#  ['18568', '1'],
#  ['18569', '1'],
#  ['18570', '1'],
#  ['18571', '1'],
#  ['18572', '1'],
#  ['18573', '1'],
#  ['18574', '1'],
#  ['18575', '1'],
#  ['18576', '1'],
#  ['18577', '1'],
#  ['18578', '1'],
#  ['18579', '1'],
#  ['18580', '1'],
#  ['18581', '1'],
#  ['18582', '1'],
#  ['18583', '1'],
#  ['18584', '1'],
#  ['18585', '1'],
#  ['18586', '1'],
#  ['18587', '1'],
#  ['18588', '1'],
#  ['18589', '1'],
#  ['18590', '1'],
#  ['18591', '1'],
# ...

# %%
for i in res:
    i[0] = i[0][:-4]

# %%
import pandas as pd
df = pd.DataFrame(res)

# %%
df.head()
# Out:
#        0   1
# 0  18540  30
# 1  18541  31
# 2  18542  29
# 3  18543  72
# 4  18544  68

# %%
df.to_csv('finalpredict.csv')

# %%
os.getcwd()
# Out:
# 'D:\\WORK\\hackerearth Challenge\\flower\\final segmented_image\\test'

# %%
predict = model.predict_generator(test_generator,steps = 1)

# %%
predict[0].argmax()

# %%
conf[18]

# %%
import pandas as pd
os.chdir('D:\\WORK\\hackerearth Challenge\\flower\\final segmented_image')
df = pd.read_csv('sample_submission.csv')

# %%
df.head()

# %%
c = 0
for i, row in df.iterrows():
    c += 1
    classp = res[str(row[0])+'.jpg']
    df['category'].set_value(i,str(classp))
    if c % 200 == 0:
        print(c)

# %%
df.head()

# %%
df.to_csv('result.csv')

# %%
from skimage.transform import resize
target_size = (256, 256)
res = {}
test_path = 'D:\\WORK\\hackerearth Challenge\\flower\\final segmented_image\\my_data\\train'
os.chdir(test_path)
der = os.listdir()
l = []
for j in der:

    os.chdir(j)
    test_img = os.listdir()
    

    for i in test_img[:1]:
        print(i)
        face_crop = cv2.imread(i)
        face_crop = cv2.resize(face_crop, target_size)
        face_crop = face_crop.astype("float") / 255.0
        face_crop = img_to_array(face_crop)
        face_crop = np.expand_dims(face_crop, axis=0)

        conf = model.predict(face_crop)[0]
        idx = np.argmax(conf)
        res[i] = str(classes[idx][6:])
        l.append(str(classes[idx][6:]))
    os.chdir(test_path)

# %%
s = set(l)

# %%
len(s)
